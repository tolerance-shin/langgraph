# %% [markdown]
# [이 파일은 다음 위치로 이동되었습니다](https://github.com/langchain-ai/langgraph/blob/23961cff61a42b52525f3b20b4094d8d2fba1744/docs/docs/tutorials/reflection/reflection.ipynb)

# %% [markdown]
# 이 디렉터리는 보관 목적만을 위해 유지되며 더 이상 업데이트되지 않습니다. 이전에 이곳에 있던 예제는 [통합된 LangChain 문서](https://docs.langchain.com/oss/python/langgraph/overview)로 이동되었습니다.
